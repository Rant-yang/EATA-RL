# %%
import baostock as bs
import pandas as pd

lg = bs.login()
print('login respond error_code:'+lg.error_code)
print('login respond  error_msg:'+lg.error_msg)
# Out:
# login success!
# login respond error_code:0
# login respond  error_msg:success

# %%
rs = bs.query_sz50_stocks()

print('query_sz50 error_code:'+rs.error_code)

print('query_sz50  error_msg:'+rs.error_msg)
# Out:
# query_sz50 error_code:0
# query_sz50  error_msg:success

# %%
sz50_stocks = rs.get_data()
sz50_stocks
# Out:
#     updateDate       code code_name
# 0   2023-03-20  sh.600010      包钢股份
# 1   2023-03-20  sh.600028      中国石化
# 2   2023-03-20  sh.600030      中信证券
# 3   2023-03-20  sh.600031      三一重工
# 4   2023-03-20  sh.600036      招商银行
# 5   2023-03-20  sh.600048      保利发展
# 6   2023-03-20  sh.600104      上汽集团
# 7   2023-03-20  sh.600111      北方稀土
# 8   2023-03-20  sh.600196      复星医药
# 9   2023-03-20  sh.600276      恒瑞医药
# 10  2023-03-20  sh.600309      万华化学
# 11  2023-03-20  sh.600346      恒力石化
# 12  2023-03-20  sh.600406      国电南瑞
# 13  2023-03-20  sh.600436       片仔癀
# 14  2023-03-20  sh.600438      通威股份
# 15  2023-03-20  sh.600519      贵州茅台
# 16  2023-03-20  sh.600585      海螺水泥
# 17  2023-03-20  sh.600690      海尔智家
# 18  2023-03-20  sh.600745      闻泰科技
# 19  2023-03-20  sh.600809      山西汾酒
# 20  2023-03-20  sh.600887      伊利股份
# 21  2023-03-20  sh.600893      航发动力
# 22  2023-03-20  sh.600900      长江电力
# 23  2023-03-20  sh.600905      三峡能源
# 24  2023-03-20  sh.601012      隆基绿能
# 25  2023-03-20  sh.601066      中信建投
# 26  2023-03-20  sh.601088      中国神华
# 27  2023-03-20  sh.601166      兴业银行
# 28  2023-03-20  sh.601225      陕西煤业
# 29  2023-03-20  sh.601288      农业银行
# 30  2023-03-20  sh.601318      中国平安
# 31  2023-03-20  sh.601398      工商银行
# 32  2023-03-20  sh.601601      中国太保
# 33  2023-03-20  sh.601628      中国人寿
# 34  2023-03-20  sh.601633      长城汽车
# 35  2023-03-20  sh.601668      中国建筑
# 36  2023-03-20  sh.601669      中国电建
# 37  2023-03-20  sh.601688      华泰证券
# 38  2023-03-20  sh.601857      中国石油
# 39  2023-03-20  sh.601888      中国中免
# 40  2023-03-20  sh.601899      紫金矿业
# 41  2023-03-20  sh.601919      中远海控
# 42  2023-03-20  sh.601995      中金公司
# 43  2023-03-20  sh.603259      药明康德
# 44  2023-03-20  sh.603260      合盛硅业
# 45  2023-03-20  sh.603288      海天味业
# 46  2023-03-20  sh.603501      韦尔股份
# 47  2023-03-20  sh.603799      华友钴业
# 48  2023-03-20  sh.603986      兆易创新
# 49  2023-03-20  sh.688599      天合光能

# %%
# import pandas as pd
# df = pd.DataFrame()
# for c in sz50_stocks.code:
#     rs = bs.query_history_k_data_plus(c, "date,code,close", start_date='2017-07-01', end_date='2022-11-18', frequency="d", adjustflag="3")
#     print(rs.get_data())
#     df = df.append(rs.get_data())

# def get_data(c):
#     rs = bs.query_history_k_data_plus(c, "date,code,close", start_date='2017-07-01', end_date='2022-11-18', frequency="d", adjustflag="3")
#     return rs.get_data()
# dfs = [get_data(c) for c in sz50_stocks.code]
# reduce(lambda a,b:a.join(b),dfs)

# %%
c = sz50_stocks.code.sample(1).iloc[0]

c
# Out:
# 'sh.600887'

# %%
import baostock as bs
import pandas as pd

#### 登陆系统 ####
lg = bs.login()
# 显示登陆返回信息
print('login respond error_code:'+lg.error_code)
print('login respond  error_msg:'+lg.error_msg)

#### 获取沪深A股历史K线数据 ####
# 详细指标参数，参见“历史行情指标参数”章节；“分钟线”参数与“日线”参数不同。“分钟线”不包含指数。
# 分钟线指标：date,time,code,open,high,low,close,volume,amount,adjustflag
# 周月线指标：date,code,open,high,low,close,volume,amount,adjustflag,turn,pctChg
rs = bs.query_history_k_data_plus(c,
    "date,code,open,high,low,close,preclose,volume,amount,adjustflag,turn,tradestatus,pctChg,isST",
    start_date='2023-01-01', end_date='2023-08-31',
    frequency="d", adjustflag="3")
print('query_history_k_data_plus respond error_code:'+rs.error_code)
print('query_history_k_data_plus respond  error_msg:'+rs.error_msg)

# rs.get_data()

#### 打印结果集 ####
data_list = []
while (rs.error_code == '0') & rs.next():
    # 获取一条记录，将记录合并在一起
    data_list.append(rs.get_row_data())
df = pd.DataFrame(data_list, columns=rs.fields)

# #### 结果集输出到csv文件 ####   
# result.to_csv("D:\\history_A_stock_k_data.csv", index=False)
# print(result)

#### 登出系统 ####
bs.logout()

df
# Out:
# login success!
# login respond error_code:0
# login respond  error_msg:success
# query_history_k_data_plus respond error_code:0
# query_history_k_data_plus respond  error_msg:success
# logout success!
#            date       code     open     high      low    close preclose  \
# 0    2023-01-03  sh.600887  31.0000  31.0700  30.3300  30.7000  31.0000
# 1    2023-01-04  sh.600887  30.7000  30.9400  30.5000  30.5800  30.7000
# 2    2023-01-05  sh.600887  30.8300  31.6000  30.7700  31.5400  30.5800
# 3    2023-01-06  sh.600887  31.7000  31.7000  31.2400  31.5000  31.5400
# 4    2023-01-09  sh.600887  31.4500  31.7900  31.2000  31.6000  31.5000
# ..          ...        ...      ...      ...      ...      ...      ...
# 142  2023-08-04  sh.600887  28.6900  28.8600  28.3100  28.3100  28.5100
# 143  2023-08-07  sh.600887  28.3100  28.3600  28.0200  28.1100  28.3100
# 144  2023-08-08  sh.600887  28.1000  28.2500  27.9200  28.0900  28.1100
# 145  2023-08-09  sh.600887  28.0500  28.2100  28.0200  28.1600  28.0900
# 146  2023-08-10  sh.600887  28.1600  28.2400  27.7100  27.8700  28.1600
#
#        volume           amount adjustflag      turn tradestatus     pctChg  \
# 0    41192622  1259875523.9900          3  0.653000           1  -0.967700
# 1    27184860   834441953.0200          3  0.431000           1  -0.390900
# 2    53318052  1674666690.2800          3  0.845200           1   3.139300
# 3    33750701  1060969782.9900          3  0.535000           1  -0.126800
# 4    44171044  1393853565.1200          3  0.700200           1   0.317500
# ..        ...              ...        ...       ...         ...        ...
# 142  36647585  1045135196.7600          3  0.584000           1  -0.701500
# 143  30134297   847668264.4600          3  0.480200           1  -0.706500
# 144  24056704   675538525.3000          3  0.383300           1  -0.071100
# 145  22449051   631168051.8200          3  0.357700           1   0.249200
# 146  33115290   922126391.0400          3  0.527700           1  -1.029800
#
#     isST
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
# ..   ...
# 142    0
# 143    0
# 144    0
# 145    0
# 146    0
#
# [147 rows x 14 columns]

# %%
df[['open',	'high',	'low',	'close',		'volume',	'amount']] = df[['open',	'high',	'low',	'close','volume',	'amount']].astype(float)

# %%
from stockstats import StockDataFrame
sdf = StockDataFrame(df)
sdf = sdf[['close','kdjk','kdjd','kdjj','rsi_6',"rsi_12",'rsi_24','close_-2_d']]
sdf['rsi_diff'] = sdf['rsi_6'] - sdf['rsi_12']
sdf['kdj_diff'] = sdf['kdjj'] - sdf['kdjd']
sdf['kdj_diff'] = (sdf['kdj_diff'] - sdf['kdj_diff'].mean())/sdf['kdj_diff'].std()
sdf['rsi_diff'] = (sdf['rsi_diff'] - sdf['rsi_diff'].mean())/sdf['rsi_diff'].std()
sdf[['close']].plot(subplots=True,figsize=(20,3), grid=True)
# Out:
# array([<Axes: >], dtype=object)

# %%
kr = sdf['kr'] = sdf['kdj_diff'] # + sdf['rsi_diff']
sdf.plot(y=['kr'],subplots=True,kind='bar',figsize=(20,2),  grid=True, alpha=0.7, color='green')
# Out:
# array([<Axes: title={'center': 'kr'}>], dtype=object)

# %%
kr1 = kr.fillna(0).shift(1).fillna(0)
flex = kr[kr*kr1 <0].index # 拐点
flex = pd.DataFrame(flex,columns=['a'])
flex['b'] = flex.a.shift(-1).dropna().astype("Int32")
flex.dropna(inplace=True)

top_row = pd.DataFrame({'a':[0], 'b':[flex.a[0]]})
flex = pd.concat([top_row,flex]).reset_index(drop=True)
flex
# Out:
#       a    b
# 0     0    1
# 1     1    2
# 2     2   11
# 3    11   24
# 4    24   27
# 5    27   29
# 6    29   33
# 7    33   36
# 8    36   40
# 9    40   50
# 10   50   61
# 11   61   62
# 12   62   63
# 13   63   69
# 14   69   72
# 15   72   76
# 16   76   86
# 17   86   90
# 18   90   92
# 19   92   99
# 20   99  106
# 21  106  118
# 22  118  123
# 23  123  126
# 24  126  127
# 25  127  134
# 26  134  143

# %%
kr = pd.DataFrame(kr).fillna(0)
kr.head(20)
# Out:
#     kdj_diff
# 0   0.003750
# 1  -0.392861
# 2   0.978884
# 3   1.238702
# 4   1.255721
# 5   1.398395
# 6   0.962695
# 7   0.448982
# 8   0.520590
# 9   0.518040
# 10  0.648695
# 11 -0.801407
# 12 -1.177706
# 13 -1.478704
# 14 -0.581577
# 15 -0.966869
# 16 -1.030263
# 17 -1.019582
# 18 -1.465437
# 19 -1.596126

# %%
def seg_cumsum(x):
    kr.iloc[x.a:x.b] = kr.iloc[x.a:x.b].cumsum()
    return kr.iloc[x.a:x.b]
       
flex.apply(seg_cumsum, axis=1)
# Out:
# 0                                  kdj_diff
# 0   0.00375
# 1                                  kdj_diff
# 1 -0.392861
# 2         kdj_diff
# 2   0.978884
# 3   2.217586
# 4   3.4...
# 3          kdj_diff
# 11  -0.801407
# 12  -1.979113
# 13  ...
# 4         kdj_diff
# 24  0.168373
# 25  0.612037
# 26  0.6...
# 5                    kdj_diff
# 27 -0.155663
# 28 -0.620594
# 6         kdj_diff
# 29  0.883765
# 30  2.549834
# 31  3.5...
# 7         kdj_diff
# 33 -0.639188
# 34 -1.461798
# 35 -2.1...
# 8         kdj_diff
# 36  0.584549
# 37  1.710797
# 38  2.8...
# 9         kdj_diff
# 40 -0.867869
# 41 -2.128127
# 42 -3.5...
# 10        kdj_diff
# 50  0.458231
# 51  1.119905
# 52  2.0...
# 11                                kdj_diff
# 61 -0.162511
# 12                                kdj_diff
# 62  0.215833
# 13        kdj_diff
# 63 -0.445246
# 64 -1.707014
# 65 -3.2...
# 14        kdj_diff
# 69  0.417817
# 70  0.759010
# 71  0.8...
# 15        kdj_diff
# 72 -0.058862
# 73 -0.577329
# 74 -0.8...
# 16         kdj_diff
# 76   0.453921
# 77   2.151332
# 78  ...
# 17        kdj_diff
# 86 -0.016017
# 87 -0.974833
# 88 -2.6...
# 18                   kdj_diff
# 90  0.087640
# 91  0.534177
# 19        kdj_diff
# 92 -0.493580
# 93 -1.852682
# 94 -3.4...
# 20         kdj_diff
# 99   0.234754
# 100  0.734502
# 101 ...
# 21         kdj_diff
# 106 -0.215499
# 107 -1.209459
# 108 ...
# 22         kdj_diff
# 118  1.187012
# 119  3.353136
# 120 ...
# 23         kdj_diff
# 123 -0.325732
# 124 -0.727335
# 125 ...
# 24                               kdj_diff
# 126  0.492468
# 25         kdj_diff
# 127 -0.496914
# 128 -1.385093
# 129 ...
# 26         kdj_diff
# 134  0.337267
# 135  0.857773
# 136 ...
# dtype: object

# %%
kr.head(30)
# Out:
#      kdj_diff
# 0    0.003750
# 1   -0.392861
# 2    0.978884
# 3    2.217586
# 4    3.473308
# 5    4.871703
# 6    5.834398
# 7    6.283380
# 8    6.803970
# 9    7.322010
# 10   7.970706
# 11  -0.801407
# 12  -1.979113
# 13  -3.457817
# 14  -4.039394
# 15  -5.006263
# 16  -6.036526
# 17  -7.056108
# 18  -8.521545
# 19 -10.117671
# 20 -11.672094
# 21 -12.806452
# 22 -13.399259
# 23 -13.723159
# 24   0.168373
# 25   0.612037
# 26   0.684570
# 27  -0.155663
# 28  -0.620594
# 29   0.883765

# %%
kr.plot(subplots=True,kind='bar',figsize=(10,2),  grid=True, alpha=0.7, color='green')
# Out:
# array([<Axes: title={'center': 'kdj_diff'}>], dtype=object)

# %%
sdf.close.plot(kind='line',figsize=(10,2),  grid=True, alpha=0.7, color='green')
# Out:
# <Axes: >

# %%
sdf[['kdjj','kdjd']].plot(subplots=False,figsize=(20,2), grid=True)
# Out:
# <Axes: >

# %%
sdf[['rsi_6','rsi_12']].tail(50).plot(subplots=False,figsize=(10,2), grid=True)
# Out:
# <Axes: >

# %%
d1 = pd.read_csv("Test/Macd/20230307.1510sh.601211.csv", index_col=0)
d1[['close', 'action', 'reward']].tail(50).plot(subplots=True,figsize=(10,5), grid=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
d1.reward.mean()
# Out:
# -0.024913954009594376

# %%
rsi = df.ta.rsi(14)
kdj = df.ta.kdj()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/5z/7l96pnn14y9_hv9w5nnbtxs00000gn/T/ipykernel_20370/3222651033.py in <module>
# ----> 1 rsi = df.ta.rsi(14)
#       2 kdj = df.ta.kdj()
#
# /usr/local/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'ta'

# %%
kdj
# Out:
#          K_9_3      D_9_3      J_9_3
# 0          NaN        NaN        NaN
# 1          NaN        NaN        NaN
# 2          NaN        NaN        NaN
# 3          NaN        NaN        NaN
# 4          NaN        NaN        NaN
# ..         ...        ...        ...
# 239  37.896686  47.178565  19.332929
# 240  34.292235  42.883122  17.110463
# 241  42.305935  42.690726  41.536352
# 242  58.973187  48.118213  80.683135
# 243  61.537680  52.591369  79.430303
#
# [244 rows x 3 columns]

# %%
import numpy as np
def super_smoother(data:np.array, length) -> np.array:
    a1 = np.exp(-1.414 * 3.14159 / (0.5 * length))
    b1 = 2 * a1 * np.cos(1.414 * 180 / (0.5 * length))
    c2 = b1
    c3 = -a1 * a1
    c1 = 1 - c2 - c3

    # filt = [0] * len(data)
    filt = np.zeros_like(data)
    filt[0] = data[0]
    filt[1] = c1 * (data[0] + data[1]) / 2 + (c2+c3) * filt[0]
    for i in range(2, len(data)):
        filt[i] = c1 * (data[i] + data[i - 1]) / 2 + c2 * filt[i - 1] + c3 * filt[i - 2]
        
    return filt

# data = [100, 110, 120, 115, 130, 142, 122, 108, 130]
data = df.close
smoothed = super_smoother(data, length=20)

# %%
import seaborn as sns
sns.lineplot((data,smoothed))
# Out:
# <Axes: >

# %%
import pandas as pd
import numpy as np

def reflex_indicator(data:np.array, length):
    # Gently smooth the data in a SuperSmoother
    filt = super_smoother(data, length)


    # Length is assumed cycle period 
    # slope = (filt[-length - 1] - filt[-1]) / length
    # 计算斜率，上面代码有问题 
    slope = (filt - pd.DataFrame(filt).shift(length).values.squeeze(1))/length
    # print(slope)

    # Sum the differences
    from functools import reduce
    sum = np.zeros_like(filt)
    diff = lambda c: filt[i-length] + c * slope[i] - filt[i-length+c]
    for i in range(length, len(filt)):
        diffs = [diff(c) for c in range(0,length)]
        sum[i] = reduce(lambda a,b: a + b, diffs)
    sum /= length
    # print(sum)
        
    # summation = 0
    # for count in range(1, length + 1):
    #     summation += (filt[-1] + count * slope) - filt[-count]
    # summation /= length

    # Normalize in terms of Standard Deviations
    # ms = 0.04 * summation * summation + 0.96 * ms[-1]
    ms = np.zeros_like(filt)
    ms[0] = sum[0]**2
    for i in range(1,len(filt)):
        ms[i] = 0.04*sum[i]**2 + 0.96*ms[i-1]

    # if ms != 0:
    reflex = sum / np.sqrt(ms)
    return reflex

# 示例用法
length = 20
# data = [100, 110, 120, 115, 130, 142, 122, 108, 130]
data = df.close
reflex = reflex_indicator(data, length)
reflex
# Out:
# /var/folders/5z/7l96pnn14y9_hv9w5nnbtxs00000gn/T/ipykernel_43852/2570837502.py:38: RuntimeWarning: invalid value encountered in true_divide
#   reflex = sum / np.sqrt(ms)
# array([        nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#         5.        ,  3.4866841 ,  3.05286034,  2.83496017,  2.83243698,
#         2.78056432,  2.25568379,  1.22274215,  0.04928833,  0.10676744,
#         1.41581457,  2.97980987,  3.6304757 ,  3.45949509,  3.13117193,
#         2.81728575,  2.4881175 ,  2.08151228,  1.59288897,  1.12521615,
#         0.70665896,  0.2459854 , -0.30041455, -0.76628071, -0.89064452,
#        -0.83276894, -0.89182294, -1.13791371, -1.55774419, -1.82011712,
#        -1.69011092, -1.02068318,  0.04316255,  0.95527903,  1.46762531,
#         1.61257502,  1.54394508,  1.21643717,  0.76029623,  0.65273844,
#         0.99420571,  1.39676266,  1.72281132,  1.93440931,  1.93367804,
#         1.69633774,  1.26564058,  0.67027052,  0.1855851 ,  0.04212102,
#         0.28955583,  0.8410162 ,  1.15277704,  1.27653333,  1.227987  ,
#         0.83060685,  0.03581112, -1.14697038, -2.1035056 , -2.44839663,
#        -2.49923391, -2.48196687, -2.29737554, -2.02366384, -1.81740491,
#        -1.61438756, -1.38057238, -1.18786805, -0.97061768, -0.71806009,
#        -0.38418277,  0.05579701,  0.44800315,  0.77310579,  0.96548948,
#         0.98981886,  0.80643723,  0.52951231,  0.35726956,  0.25856632,
#         0.11627309, -0.08165714, -0.1723044 , -0.16481478, -0.17247206,
#        -0.05338237,  0.17415513,  0.36850265,  0.45527183,  0.42921281,
#         0.39780011,  0.56560345,  0.94216646,  1.37620964,  1.77345097,
#         1.89426519,  1.646217  ,  1.23656643,  0.92748972,  0.62449557,
#         0.16303456, -0.33809625, -0.68960771, -0.89370779, -1.00705693,
#        -1.01059569, -1.09760125, -1.40689895, -1.7568135 , -2.04489807,
#        -2.21006927, -2.12285888, -1.88888704, -1.55635253, -1.08296416,
#        -0.58365175, -0.2222164 , -0.03018566,  0.20475152,  0.51599106,
# 1877        0.995406
# 1878        0.996923
# 1879        1.001543
# 1880        1.009245
# 1881        0.983206
# 1882        1.001553
# 1883        0.995370
# 1884        0.974436
# 1885        1.001504
# 1886        0.984985
# 1887        1.010786
# 1888        0.993874
# 1889        1.025118
# 1890        1.001572
# 1891        1.000000
# 1892        0.984520
# 1893        1.030303
# 1894        1.006421
# 1895        0.995208
# 1896        1.009677
# 1897        0.988836
# 1898        0.961722
# 1899        1.006678

# %%
df.tail(100).action.plot(kind="line")
# Out:
# <Axes: >

# %%
from stockstats import StockDataFrame
sdf = StockDataFrame(df)
# stockStat = stockstats.StockDataFrame.retype(stock)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'kdjd'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/lib/python3.9/site-packages/stockstats.py:1714, in StockDataFrame.__getitem__(self, item)
#    1713 try:
# -> 1714     result = wrap(super(StockDataFrame, self).__getitem__(item))
#    1715 except KeyError:
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#
# KeyError: 'kdjd'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'kdjk'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/lib/python3.9/site-packages/stockstats.py:1714, in StockDataFrame.__getitem__(self, item)
#    1713 try:
# -> 1714     result = wrap(super(StockDataFrame, self).__getitem__(item))
#    1715 except KeyError:
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#
# KeyError: 'kdjk'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'low'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/lib/python3.9/site-packages/stockstats.py:1714, in StockDataFrame.__getitem__(self, item)
#    1713 try:
# -> 1714     result = wrap(super(StockDataFrame, self).__getitem__(item))
#    1715 except KeyError:
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#
# KeyError: 'low'
#
# During handling of the above exception, another exception occurred:
#
# UserWarning                               Traceback (most recent call last)
# Cell In[18], line 3
#       1 from stockstats import StockDataFrame
#       2 sdf = StockDataFrame(df)
# ----> 3 sdf['kdjd']
#
# File ~/miniconda3/lib/python3.9/site-packages/stockstats.py:1721, in StockDataFrame.__getitem__(self, item)
#    1719             self.__init_column(column)
#    1720     else:
# -> 1721         self.__init_column(item)
#    1722 except AttributeError:
#    1723     pass
#
# File ~/miniconda3/lib/python3.9/site-packages/stockstats.py:1710, in StockDataFrame.__init_column(self, key)
#    1708     self[key] = []
#    1709 else:
# -> 1710     self.__init_not_exist_column(key)
#
# File ~/miniconda3/lib/python3.9/site-packages/stockstats.py:1686, in StockDataFrame.__init_not_exist_column(self, key)
#    1684 for names, handler in self.handler.items():
#    1685     if key in names:
# -> 1686         return _call_handler(handler)
#    1688 if key.endswith('_delta'):
#    1689     self._get_delta(key)
#
# File ~/miniconda3/lib/python3.9/site-packages/stockstats.py:215, in _call_handler(handler)
#     213 def _call_handler(handler: Callable):
#     214     meta = _Meta(handler.__name__[5:])
# --> 215     return handler(meta)
#
# File ~/miniconda3/lib/python3.9/site-packages/stockstats.py:904, in StockDataFrame._get_kdjd(self, meta)
#     898 """ Get the D of KDJ
#     899
#     900 D = 2/3 × (prev. D) +1/3 × (curr. K)
#     901 2/3 and 1/3 are the smooth parameters.
#     902 """
#     903 k_column = meta.name.replace('kdjd', 'kdjk')
# --> 904 self[meta.name] = list(self._calc_kd(self.get(k_column)))
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/generic.py:4311, in NDFrame.get(self, key, default)
#    4265 """
#    4266 Get item from object for given key (ex: DataFrame column).
#    4267
#    (...)
#    4308 'default_value'
#    4309 """
#    4310 try:
# -> 4311     return self[key]
#    4312 except (KeyError, ValueError, IndexError):
#    4313     return default
#
# File ~/miniconda3/lib/python3.9/site-packages/stockstats.py:1721, in StockDataFrame.__getitem__(self, item)
#    1719             self.__init_column(column)
#    1720     else:
# -> 1721         self.__init_column(item)
#    1722 except AttributeError:
#    1723     pass
#
# File ~/miniconda3/lib/python3.9/site-packages/stockstats.py:1710, in StockDataFrame.__init_column(self, key)
#    1708     self[key] = []
#    1709 else:
# -> 1710     self.__init_not_exist_column(key)
#
# File ~/miniconda3/lib/python3.9/site-packages/stockstats.py:1686, in StockDataFrame.__init_not_exist_column(self, key)
#    1684 for names, handler in self.handler.items():
#    1685     if key in names:
# -> 1686         return _call_handler(handler)
#    1688 if key.endswith('_delta'):
#    1689     self._get_delta(key)
#
# File ~/miniconda3/lib/python3.9/site-packages/stockstats.py:215, in _call_handler(handler)
#     213 def _call_handler(handler: Callable):
#     214     meta = _Meta(handler.__name__[5:])
# --> 215     return handler(meta)
#
# File ~/miniconda3/lib/python3.9/site-packages/stockstats.py:894, in StockDataFrame._get_kdjk(self, meta)
#     888 """ Get the K of KDJ
#     889
#     890 K ＝ 2/3 × (prev. K) +1/3 × (curr. RSV)
#     891 2/3 and 1/3 are the smooth parameters.
#     892 """
#     893 window = meta.int
# --> 894 rsv = self._rsv(window)
#     895 self[meta.name] = list(self._calc_kd(rsv))
#
# File ~/miniconda3/lib/python3.9/site-packages/stockstats.py:436, in StockDataFrame._rsv(self, window)
#     435 def _rsv(self, window):
# --> 436     low_min = self.mov_min(self['low'], window)
#     437     high_max = self.mov_max(self['high'], window)
#     439     cv = (self['close'] - low_min) / (high_max - low_min)
#
# File ~/miniconda3/lib/python3.9/site-packages/stockstats.py:1721, in StockDataFrame.__getitem__(self, item)
#    1719             self.__init_column(column)
#    1720     else:
# -> 1721         self.__init_column(item)
#    1722 except AttributeError:
#    1723     pass
#
# File ~/miniconda3/lib/python3.9/site-packages/stockstats.py:1710, in StockDataFrame.__init_column(self, key)
#    1708     self[key] = []
#    1709 else:
# -> 1710     self.__init_not_exist_column(key)
#
# File ~/miniconda3/lib/python3.9/site-packages/stockstats.py:1700, in StockDataFrame.__init_not_exist_column(self, key)
#    1698     col = None
#    1699 else:
# -> 1700     raise UserWarning("Invalid number of return arguments "
#    1701                       f"after parsing column name: '{key}'")
#    1702 meta = _Meta(name, windows=n, column=col)
#    1703 getattr(self, f'_get_{name}')(meta)
#
# UserWarning: Invalid number of return arguments after parsing column name: 'low'

# %%
from globals import summary, etf_action
import os
from pathlib import Path
from functools import reduce
import pandas as pd

data_folder = Path(f"Test/Kdj")
files = os.listdir(str(data_folder))  # 目录下所有文件,
files = [f for f in files if os.path.splitext(f)[1] == '.csv']  # 只选择 .csv 文件,
if summary in files: 
    files.remove(summary)
if etf_action in files: 
    files.remove(etf_action)  # 如果已经有了要去掉
print(f"Testing ETF strategy Kdj with {files}")
# 读取所有files，组成一个dataframe或者list of dataframe
df_list = [pd.read_csv(data_folder/f, index_col=0 ,header=0) for f in files]
df_list = reduce(lambda a,b: pd.concat([a,b]), df_list)
df_list = df_list.sort_values(by=['date', 'ticker']).reset_index(drop=True) # 按时间-股票对排序,并且去掉index
days = df_list.date.drop_duplicates() # 去掉重复的日期
days
# Out:
# Testing ETF strategy Kdj with ['20230805.0901sh.600588.csv', '20230805.1544sh.600030.csv', '20230805.1544sh.600031.csv', '20230805.1544sh.600196.csv', '20230805.1544sh.600036.csv', '20230805.1544sh.600010.csv', '20230805.1544sh.600028.csv', '20230805.1544sh.600111.csv', '20230805.1544sh.600104.csv', '20230805.0901sh.603986.csv', '20230805.1544sh.600048.csv', '20230805.1544sh.600276.csv']
# 0        2015-10-26
# 3        2015-10-27
# 6        2015-10-28
# 16       2015-10-29
# 26       2015-10-30
#             ...
# 22288    2023-07-31
# 22300    2023-08-01
# 22312    2023-08-02
# 22324    2023-08-03
# 22336    2023-08-04
# Name: date, Length: 1895, dtype: object

# %%
for day in days:
    print(day)
    df = df_list[df_list.date == day]
    # print(df)
    df = df.sort_values(by=['date', 'ticker']).reset_index(drop=True) # 按时间-股票对排序,并且去掉index

# %%
df_list.columns
# Out:
# Index(['ticker', 'date', 'close', 'action', 'reward', 'change_wo_short',
#        'change_w_short'],
#       dtype='object')
